# %% [markdown]
# <a href="https://colab.research.google.com/github/rzeta0/Make-Your-Own-Mandelbrot/blob/main/DEM_Julia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Julia Setby Disstance Estimator **
#
# "Make Your Own Mandelbrot" Second Edition
#
# This work is licensed under CC BY-SA 4.0

# %%
# import libraries

import numpy as np
import matplotlib.pyplot as plt

# %%
# number of pixels wide and high
resolution = 1024

# bottom left corner of square viewport
bottom_left = complex(0,-0.5)

# width and height of square viewport
size = 1

# maximum iterations per test
max_iter = 1024

# %%
# value of c

# Examnple 1: Filament
#c = complex(-0.76796, 0.17689)

# Example 2: Cauliflower
#c = complex(0.30195,0.0191)

# Example 3: Rabbit
#c = complex(-0.170,0.750)

# Example 4: Lightning
#c = complex(-1.2456,0.34196)

# Example 5: Temples
#c = complex(-1.25,0)

# Example 6: Filament 2
c = complex(-0.8, 0.16)

# magnitude of c
abs_c = abs(c)

# %%
# create image as numpy array

image = np.full( (resolution,resolution), 255)

# %%
# create image as numpy array

image = np.full( (resolution,resolution), 255)

###############################

# test each point in viewport for divergence

# visit every pixel in the image array
for x in range(resolution):
  for y in range(resolution):

    # convert pixel grid location x,y to initial z_0
    z = bottom_left + (size * complex(x/(resolution-1), y/(resolution-1)))
    dz = complex(1,0)

    # test for divergence
    for iteration_count in range(1,max_iter+1):
      dz = 2.0 * z * dz
      z = (z*z) + c
      abs_z = abs(z)
      if (abs_z > 4): break
      pass

    de = 2 * abs_z * np.log(abs_z) / abs(dz)

    # colour pixel according to divergence
    image[y,x] = (255) * np.tanh(de*resolution*2)

    pass # end y loop
  pass # end x loop

# %%
# render image

# create figure of size 6x6
fig, ax = plt.subplots()
fig.set_size_inches(6,6)

# turn of axis ticks
ax.set_xticks([])
ax.set_yticks([])

# grey outline
grey_value = str(0.7)
ax.spines['bottom'].set_color(grey_value)
ax.spines['top'].set_color(grey_value)
ax.spines['right'].set_color(grey_value)
ax.spines['left'].set_color(grey_value)

# plot image array, using grey colour palette
ax.imshow(image, cmap='gray', origin="lower")

# add value of c
ax.text(10, 10, "c = "+str(c.real)+" "+str(c.imag)+"i", fontsize=10)

plt.tight_layout()

# export the figure as a PNG image file
plt.savefig("julia_dem.png", dpi=600, format="png")
plt.savefig("julia_dem.pdf", dpi=600, format="pdf")

plt.show()
